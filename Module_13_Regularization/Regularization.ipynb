# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit-futuremakers-summer-2024-faefey/blob/main/Module_13_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 116MB/s]
# Epoch 1/20
# 24/24 [==============================] - 3s 32ms/step - loss: 0.8869 - accuracy: 0.6160 - val_loss: 0.7393 - val_accuracy: 0.6517
# Epoch 2/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.6728 - accuracy: 0.6984 - val_loss: 0.6011 - val_accuracy: 0.7564
# Epoch 3/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5228 - accuracy: 0.8114 - val_loss: 0.5314 - val_accuracy: 0.7967
# Epoch 4/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4188 - accuracy: 0.8537 - val_loss: 0.5083 - val_accuracy: 0.7959
# Epoch 5/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.3509 - accuracy: 0.8744 - val_loss: 0.5043 - val_accuracy: 0.8035
# Epoch 6/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2988 - accuracy: 0.8941 - val_loss: 0.5129 - val_accuracy: 0.8065
# Epoch 7/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2559 - accuracy: 0.9122 - val_loss: 0.5387 - val_accuracy: 0.8020
# Epoch 8/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2218 - accuracy: 0.9232 - val_loss: 0.5673 - val_accuracy: 0.7898
# Epoch 9/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1917 - accuracy: 0.9368 - val_loss: 0.5902 - val_accuracy: 0.7883
# Epoch 10/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1661 - accuracy: 0.9464 - val_loss: 0.6400 - val_accuracy: 0.7785
# Epoch 11/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1446 - accuracy: 0.9540 - val_loss: 0.6859 - val_accuracy: 0.7769
# Epoch 12/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.1269 - accuracy: 0.9602 - val_loss: 0.6987 - val_accuracy: 0.7838
# Epoch 13/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1116 - accuracy: 0.9641 - val_loss: 0.7466 - val_accuracy: 0.7724
# Epoch 14/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0978 - accuracy: 0.9692 - val_loss: 0.7696 - val_accuracy: 0.7792
# Epoch 15/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0869 - accuracy: 0.9723 - val_loss: 0.8015 - val_accuracy: 0.7830
# Epoch 16/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0769 - accuracy: 0.9760 - val_loss: 0.8744 - val_accuracy: 0.7656
# Epoch 17/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0698 - accuracy: 0.9790 - val_loss: 0.8766 - val_accuracy: 0.7777
# Epoch 18/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.0612 - accuracy: 0.9812 - val_loss: 0.9278 - val_accuracy: 0.7739
# Epoch 19/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0563 - accuracy: 0.9835 - val_loss: 0.9475 - val_accuracy: 0.7754
# Epoch 20/20
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0500 - accuracy: 0.9849 - val_loss: 1.0024 - val_accuracy: 0.7686
# Minimum validation loss reached in epoch 5
# Epoch 1/20
# 24/24 [==============================] - 1s 29ms/step - loss: 1.0536 - accuracy: 0.6088 - val_loss: 1.0001 - val_accuracy: 0.6866
# Epoch 2/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.9536 - accuracy: 0.7096 - val_loss: 0.9047 - val_accuracy: 0.7215
# Epoch 3/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.8516 - accuracy: 0.7457 - val_loss: 0.8133 - val_accuracy: 0.7458
# Epoch 4/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.7560 - accuracy: 0.7754 - val_loss: 0.7351 - val_accuracy: 0.7640
# Epoch 5/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.6728 - accuracy: 0.7998 - val_loss: 0.6688 - val_accuracy: 0.7800
# Epoch 6/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6036 - accuracy: 0.8152 - val_loss: 0.6188 - val_accuracy: 0.7906
# Epoch 7/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5473 - accuracy: 0.8297 - val_loss: 0.5800 - val_accuracy: 0.7989
# Epoch 8/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.5019 - accuracy: 0.8425 - val_loss: 0.5527 - val_accuracy: 0.8020
# Epoch 9/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4654 - accuracy: 0.8524 - val_loss: 0.5320 - val_accuracy: 0.8027
# Epoch 10/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.4352 - accuracy: 0.8602 - val_loss: 0.5167 - val_accuracy: 0.8058
# Epoch 11/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4097 - accuracy: 0.8660 - val_loss: 0.5088 - val_accuracy: 0.8103
# Epoch 12/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.3880 - accuracy: 0.8727 - val_loss: 0.5007 - val_accuracy: 0.8141
# Epoch 13/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3690 - accuracy: 0.8786 - val_loss: 0.4964 - val_accuracy: 0.8164
# Epoch 14/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3520 - accuracy: 0.8844 - val_loss: 0.4917 - val_accuracy: 0.8164
# Epoch 15/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3366 - accuracy: 0.8890 - val_loss: 0.4920 - val_accuracy: 0.8134
# Epoch 16/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.3224 - accuracy: 0.8951 - val_loss: 0.4897 - val_accuracy: 0.8149
# Epoch 17/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.3094 - accuracy: 0.8990 - val_loss: 0.4917 - val_accuracy: 0.8134
# Epoch 18/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2977 - accuracy: 0.9031 - val_loss: 0.4953 - val_accuracy: 0.8080
# Epoch 19/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2866 - accuracy: 0.9072 - val_loss: 0.4967 - val_accuracy: 0.8073
# Epoch 20/20
# 24/24 [==============================] - 0s 15ms/step - loss: 0.2762 - accuracy: 0.9111 - val_loss: 0.4980 - val_accuracy: 0.8096
# Minimum validation loss reached in epoch 16

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644419 (2.46 MB)
# Trainable params: 644419 (2.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 1s 32ms/step - loss: 1.0693 - accuracy: 0.6135 - val_loss: 0.8894 - val_accuracy: 0.6677
# Epoch 2/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.8055 - accuracy: 0.7201 - val_loss: 0.7330 - val_accuracy: 0.7830
# Epoch 3/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.6494 - accuracy: 0.8152 - val_loss: 0.6450 - val_accuracy: 0.8005
# Epoch 4/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.5540 - accuracy: 0.8498 - val_loss: 0.6264 - val_accuracy: 0.7982
# Epoch 5/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4927 - accuracy: 0.8688 - val_loss: 0.6120 - val_accuracy: 0.8042
# Epoch 6/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4484 - accuracy: 0.8824 - val_loss: 0.6280 - val_accuracy: 0.7936
# Epoch 7/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4119 - accuracy: 0.9000 - val_loss: 0.6454 - val_accuracy: 0.7838
# Epoch 8/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3832 - accuracy: 0.9100 - val_loss: 0.6628 - val_accuracy: 0.7876
# Epoch 9/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3591 - accuracy: 0.9195 - val_loss: 0.6675 - val_accuracy: 0.7906
# Epoch 10/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3371 - accuracy: 0.9278 - val_loss: 0.6704 - val_accuracy: 0.7982
# Epoch 11/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3205 - accuracy: 0.9351 - val_loss: 0.6989 - val_accuracy: 0.7769
# Epoch 12/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.3042 - accuracy: 0.9406 - val_loss: 0.7053 - val_accuracy: 0.7944
# Epoch 13/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2903 - accuracy: 0.9454 - val_loss: 0.7209 - val_accuracy: 0.7868
# Epoch 14/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.2783 - accuracy: 0.9484 - val_loss: 0.7321 - val_accuracy: 0.7951
# Epoch 15/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2671 - accuracy: 0.9525 - val_loss: 0.7653 - val_accuracy: 0.7686
# Epoch 16/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.2574 - accuracy: 0.9572 - val_loss: 0.7575 - val_accuracy: 0.7800
# Epoch 17/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2498 - accuracy: 0.9602 - val_loss: 0.7747 - val_accuracy: 0.7785
# Epoch 18/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.2414 - accuracy: 0.9631 - val_loss: 0.7624 - val_accuracy: 0.7898
# Epoch 19/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.2332 - accuracy: 0.9658 - val_loss: 0.7863 - val_accuracy: 0.7754
# Epoch 20/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2265 - accuracy: 0.9680 - val_loss: 0.7770 - val_accuracy: 0.7807
# Minimum validation loss reached in epoch 5

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = np.abs(weights).sum()
    return reg

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg = np.square(weights).sum()
    return reg

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of the layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644419 (2.46 MB)
# Trainable params: 644419 (2.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 29ms/step - loss: 0.8959 - accuracy: 0.6139 - val_loss: 0.7466 - val_accuracy: 0.6366
# Epoch 2/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.7286 - accuracy: 0.6531 - val_loss: 0.6488 - val_accuracy: 0.7200
# Epoch 3/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.6275 - accuracy: 0.7417 - val_loss: 0.5712 - val_accuracy: 0.7936
# Epoch 4/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.5446 - accuracy: 0.7970 - val_loss: 0.5218 - val_accuracy: 0.8035
# Epoch 5/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.4806 - accuracy: 0.8288 - val_loss: 0.4990 - val_accuracy: 0.8042
# Epoch 6/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.4349 - accuracy: 0.8460 - val_loss: 0.4923 - val_accuracy: 0.8103
# Epoch 7/20
# 24/24 [==============================] - 0s 17ms/step - loss: 0.3927 - accuracy: 0.8624 - val_loss: 0.4946 - val_accuracy: 0.8050
# Epoch 8/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.3563 - accuracy: 0.8783 - val_loss: 0.4970 - val_accuracy: 0.8111
# Epoch 9/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.3309 - accuracy: 0.8843 - val_loss: 0.5064 - val_accuracy: 0.8156
# Epoch 10/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2964 - accuracy: 0.8963 - val_loss: 0.5192 - val_accuracy: 0.8126
# Epoch 11/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2743 - accuracy: 0.9045 - val_loss: 0.5328 - val_accuracy: 0.8058
# Epoch 12/20
# 24/24 [==============================] - 0s 18ms/step - loss: 0.2574 - accuracy: 0.9142 - val_loss: 0.5466 - val_accuracy: 0.8050
# Epoch 13/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2384 - accuracy: 0.9200 - val_loss: 0.5688 - val_accuracy: 0.7997
# Epoch 14/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.2151 - accuracy: 0.9303 - val_loss: 0.5801 - val_accuracy: 0.7989
# Epoch 15/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.2047 - accuracy: 0.9305 - val_loss: 0.5908 - val_accuracy: 0.8042
# Epoch 16/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1880 - accuracy: 0.9362 - val_loss: 0.6187 - val_accuracy: 0.7967
# Epoch 17/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.1714 - accuracy: 0.9448 - val_loss: 0.6334 - val_accuracy: 0.7921
# Epoch 18/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.1657 - accuracy: 0.9454 - val_loss: 0.6532 - val_accuracy: 0.7982
# Epoch 19/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1524 - accuracy: 0.9502 - val_loss: 0.6701 - val_accuracy: 0.7944
# Epoch 20/20
# 24/24 [==============================] - 0s 16ms/step - loss: 0.1423 - accuracy: 0.9524 - val_loss: 0.6923 - val_accuracy: 0.7898
# Minimum validation loss reached in epoch 6

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3, activation='softmax')
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 51ms/step - loss: 1.0677 - accuracy: 0.6113 - val_loss: 0.9131 - val_accuracy: 0.6791
# Epoch 2/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.8901 - accuracy: 0.7086 - val_loss: 0.8553 - val_accuracy: 0.7640
# Epoch 3/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7791 - accuracy: 0.7770 - val_loss: 0.8035 - val_accuracy: 0.7807
# Epoch 4/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6693 - accuracy: 0.8361 - val_loss: 0.8328 - val_accuracy: 0.7542
# Epoch 5/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.5588 - accuracy: 0.8807 - val_loss: 0.8062 - val_accuracy: 0.7959
# Epoch 6/20
# 24/24 [==============================] - 0s 21ms/step - loss: 0.4598 - accuracy: 0.9182 - val_loss: 0.8732 - val_accuracy: 0.7860
# Epoch 7/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.3937 - accuracy: 0.9421 - val_loss: 0.9413 - val_accuracy: 0.7822
# Epoch 8/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3399 - accuracy: 0.9603 - val_loss: 0.9876 - val_accuracy: 0.7921
# Epoch 9/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.3071 - accuracy: 0.9699 - val_loss: 1.0931 - val_accuracy: 0.8035
# Epoch 10/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2782 - accuracy: 0.9780 - val_loss: 1.1669 - val_accuracy: 0.8065
# Epoch 11/20
# 24/24 [==============================] - 1s 21ms/step - loss: 0.2673 - accuracy: 0.9809 - val_loss: 1.1890 - val_accuracy: 0.7997
# Epoch 12/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2547 - accuracy: 0.9841 - val_loss: 1.2133 - val_accuracy: 0.8005
# Epoch 13/20
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2403 - accuracy: 0.9869 - val_loss: 1.2656 - val_accuracy: 0.7989
# Epoch 14/20
# 24/24 [==============================] - 1s 22ms/step - loss: 0.2369 - accuracy: 0.9861 - val_loss: 1.2246 - val_accuracy: 0.7929
# Epoch 15/20
# 24/24 [==============================] - 1s 23ms/step - loss: 0.2229 - accuracy: 0.9897 - val_loss: 1.2606 - val_accuracy: 0.7898
# Epoch 16/20
# 24/24 [==============================] - 1s 24ms/step - loss: 0.2194 - accuracy: 0.9899 - val_loss: 1.3040 - val_accuracy: 0.8005
# Epoch 17/20
# 24/24 [==============================] - 1s 26ms/step - loss: 0.2127 - accuracy: 0.9900 - val_loss: 1.2374 - val_accuracy: 0.8005
# Epoch 18/20
# 24/24 [==============================] - 1s 25ms/step - loss: 0.2048 - accuracy: 0.9922 - val_loss: 1.2425 - val_accuracy: 0.7951
# Epoch 19/20
# 24/24 [==============================] - 1s 29ms/step - loss: 0.2035 - accuracy: 0.9906 - val_loss: 1.2442 - val_accuracy: 0.8065
# Epoch 20/20
# 24/24 [==============================] - 0s 19ms/step - loss: 0.1954 - accuracy: 0.9911 - val_loss: 1.2282 - val_accuracy: 0.7982
# Minimum validation loss reached in epoch 3

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# It makes sense to add both L2 regularization and dropout when a model is severely overfitting and one regularization method is not enough to reduce the overfitting. Even though the neural network above (4 layers of 512 neurons each) is much more complex than the baseline neural network (2 layers of 64 neurons each), using both regularization methods at the same time reduced overfitting to the point that the validation loss curves are similar. The validation loss curves of the two neural networks are very similar in shape and show that the neural network above begins to overfit at around the same time as the baseline neural network, even though their complexities are very different. The curve of the neural network above even seems to flatten out and stop increasing towards the end, unlike the curve of the baseline neural network which continues to increase.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1385 - accuracy: 0.9648
# Epoch 2/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0987 - accuracy: 0.9729
# Epoch 3/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0801 - accuracy: 0.9773
# Epoch 4/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0666 - accuracy: 0.9819
# Epoch 5/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0569 - accuracy: 0.9835
# 46/46 [==============================] - 0s 3ms/step - loss: 0.9562 - accuracy: 0.7760
#
# Test accuracy: 77.60%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/16
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2893 - accuracy: 0.9050
# Epoch 2/16
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2781 - accuracy: 0.9084
# Epoch 3/16
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2677 - accuracy: 0.9115
# Epoch 4/16
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2581 - accuracy: 0.9157
# Epoch 5/16
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2491 - accuracy: 0.9181
# Epoch 6/16
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2407 - accuracy: 0.9213
# Epoch 7/16
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2325 - accuracy: 0.9248
# Epoch 8/16
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2249 - accuracy: 0.9268
# Epoch 9/16
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2176 - accuracy: 0.9306
# Epoch 10/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2108 - accuracy: 0.9321
# Epoch 11/16
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2042 - accuracy: 0.9344
# Epoch 12/16
# 26/26 [==============================] - 0s 18ms/step - loss: 0.1979 - accuracy: 0.9384
# Epoch 13/16
# 26/26 [==============================] - 1s 19ms/step - loss: 0.1921 - accuracy: 0.9397
# Epoch 14/16
# 26/26 [==============================] - 1s 20ms/step - loss: 0.1864 - accuracy: 0.9416
# Epoch 15/16
# 26/26 [==============================] - 0s 19ms/step - loss: 0.1808 - accuracy: 0.9431
# Epoch 16/16
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1755 - accuracy: 0.9454
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5728 - accuracy: 0.7917
#
# Test accuracy: 79.17%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2779 - accuracy: 0.9482
# Epoch 2/5
# 26/26 [==============================] - 0s 15ms/step - loss: 0.2506 - accuracy: 0.9565
# Epoch 3/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2355 - accuracy: 0.9620
# Epoch 4/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2271 - accuracy: 0.9641
# Epoch 5/5
# 26/26 [==============================] - 0s 14ms/step - loss: 0.2166 - accuracy: 0.9686
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7754 - accuracy: 0.7828
#
# Test accuracy: 78.28%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1942 - accuracy: 0.9400
# Epoch 2/6
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1697 - accuracy: 0.9459
# Epoch 3/6
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1591 - accuracy: 0.9514
# Epoch 4/6
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1503 - accuracy: 0.9534
# Epoch 5/6
# 26/26 [==============================] - 0s 15ms/step - loss: 0.1374 - accuracy: 0.9559
# Epoch 6/6
# 26/26 [==============================] - 0s 14ms/step - loss: 0.1263 - accuracy: 0.9617
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7891 - accuracy: 0.7903
#
# Test accuracy: 79.03%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# Here are the ways to prevent underfitting:
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# Visualize the regularized **cost function**:

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.abs(w).sum()/2
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualizations for L1 and L2 regularization, how do they help while training?

# %% [markdown]
# ### Answer
#
# By using L1 and L2 regularization when there is overfitting, training loss is able to reach a lower value than without using them. There are more contour lines closer to the middle in the visualizations for the L1 and L2 regularized loss functions, indicating that the minimum loss is lower in those visualizations.

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
